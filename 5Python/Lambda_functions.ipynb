# %%
# lambda functions
square = lambda x : x**2 # we dont have to write long codes 
# we defined lambda in one line ki what it does with square = so in another line of code we can write with just square(and) change values

# %%
# example ki just type one word and get value
square(7)
# Out:
# 49

# %%
# this is an example of writing a long function for squaring a number without lambda functions
x = 5
def square(x):
    return x**2
print(square(x))
# Out:
# 25
