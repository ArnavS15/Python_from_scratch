# %%
# we have a list of values i.e multiple values that we want to comprehensively define in 1 function

n = [1,2,3,2,4,3,4,3] # list
square = list(map(lambda x : x**2 , n)) # list ke andar we map jiske andar lamda is defined to its needed value,the source list
print(square)
# Out:
# [1, 4, 9, 4, 16, 9, 16, 9]
